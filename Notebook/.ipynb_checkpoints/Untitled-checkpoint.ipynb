# %%
import pandas as pd

# %%
data = pd.read_csv("dataset.csv")

# %%
data.sample(20)
# Out:
#          step      type     amount     nameOrig  oldbalanceOrg  \
# 4951752   351   PAYMENT    5391.91  C2141688937        1589.00
# 3639618   275   PAYMENT     664.44  C1396834204      116537.87
# 1166648   132   PAYMENT   30287.61  C1550158731           0.00
# 5306506   373   PAYMENT   22646.99   C159281689       27283.00
# 5098966   355  CASH_OUT  131315.89   C785026809        4126.00
# 527406     20   PAYMENT    2618.95  C2141059755         537.00
# 4216479   305   CASH_IN  112534.98   C383404714     5352093.47
# 493201     20   CASH_IN  451329.29   C658271670     1012984.93
# 472094     19   PAYMENT   11397.54  C1666016303       49894.00
# 1999812   179   PAYMENT    2410.81  C1389292004       21074.05
# 964450     44   CASH_IN   25905.19   C164954403       11631.00
# 4055529   300   PAYMENT   19283.65  C1038084064      100674.00
# 1838659   163  CASH_OUT   71147.01  C1526077771       93024.00
# 4447516   323   CASH_IN  444930.25  C1343413865    12697613.38
# ...

# %%
data.head(20)
# Out:
#     step      type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0      1   PAYMENT    9839.64  C1231006815      170136.00       160296.36
# 1      1   PAYMENT    1864.28  C1666544295       21249.00        19384.72
# 2      1  TRANSFER     181.00  C1305486145         181.00            0.00
# 3      1  CASH_OUT     181.00   C840083671         181.00            0.00
# 4      1   PAYMENT   11668.14  C2048537720       41554.00        29885.86
# 5      1   PAYMENT    7817.71    C90045638       53860.00        46042.29
# 6      1   PAYMENT    7107.77   C154988899      183195.00       176087.23
# 7      1   PAYMENT    7861.64  C1912850431      176087.23       168225.59
# 8      1   PAYMENT    4024.36  C1265012928        2671.00            0.00
# 9      1     DEBIT    5337.77   C712410124       41720.00        36382.23
# 10     1     DEBIT    9644.94  C1900366749        4465.00            0.00
# 11     1   PAYMENT    3099.97   C249177573       20771.00        17671.03
# ...

# %%
data.tail(20)
# Out:
#          step      type      amount     nameOrig  oldbalanceOrg  \
# 6362600   742  TRANSFER   652993.91    C40604503      652993.91
# 6362601   742  CASH_OUT   652993.91  C1614818636      652993.91
# 6362602   742  TRANSFER  1819543.69  C2089752665     1819543.69
# 6362603   742  CASH_OUT  1819543.69  C1039979813     1819543.69
# 6362604   742  TRANSFER    54652.46  C1674778854       54652.46
# 6362605   742  CASH_OUT    54652.46    C43545501       54652.46
# 6362606   742  TRANSFER   303846.74   C959102961      303846.74
# 6362607   742  CASH_OUT   303846.74  C1148860488      303846.74
# 6362608   742  TRANSFER   258355.42  C1226129332      258355.42
# 6362609   742  CASH_OUT   258355.42  C1113162093      258355.42
# 6362610   742  TRANSFER    63416.99   C778071008       63416.99
# 6362611   742  CASH_OUT    63416.99   C994950684       63416.99
# 6362612   743  TRANSFER  1258818.82  C1531301470     1258818.82
# 6362613   743  CASH_OUT  1258818.82  C1436118706     1258818.82
# ...

# %%
print(data.columns)
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='object')

# %%
data.head(10)
# Out:
#    step      type    amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1   PAYMENT   9839.64  C1231006815      170136.00       160296.36
# 1     1   PAYMENT   1864.28  C1666544295       21249.00        19384.72
# 2     1  TRANSFER    181.00  C1305486145         181.00            0.00
# 3     1  CASH_OUT    181.00   C840083671         181.00            0.00
# 4     1   PAYMENT  11668.14  C2048537720       41554.00        29885.86
# 5     1   PAYMENT   7817.71    C90045638       53860.00        46042.29
# 6     1   PAYMENT   7107.77   C154988899      183195.00       176087.23
# 7     1   PAYMENT   7861.64  C1912850431      176087.23       168225.59
# 8     1   PAYMENT   4024.36  C1265012928        2671.00            0.00
# 9     1     DEBIT   5337.77   C712410124       41720.00        36382.23
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud
# 0  M1979787155             0.0            0.00        0               0
# ...

# %%
data.size
# Out:
# 69988820

# %%
data.info
# Out:
# <bound method DataFrame.info of          step      type      amount     nameOrig  oldbalanceOrg  \
# 0           1   PAYMENT     9839.64  C1231006815      170136.00
# 1           1   PAYMENT     1864.28  C1666544295       21249.00
# 2           1  TRANSFER      181.00  C1305486145         181.00
# 3           1  CASH_OUT      181.00   C840083671         181.00
# 4           1   PAYMENT    11668.14  C2048537720       41554.00
# ...       ...       ...         ...          ...            ...
# 6362615   743  CASH_OUT   339682.13   C786484425      339682.13
# 6362616   743  TRANSFER  6311409.28  C1529008245     6311409.28
# 6362617   743  CASH_OUT  6311409.28  C1162922333     6311409.28
# 6362618   743  TRANSFER   850002.52  C1685995037      850002.52
# 6362619   743  CASH_OUT   850002.52  C1280323807      850002.52
#
#          newbalanceOrig     nameDest  oldbalanceDest  newbalanceDest  isFraud  \
# 0             160296.36  M1979787155            0.00            0.00        0
# ...

# %%
data.shape
# Out:
# (6362620, 11)

# %%
print(data['nameDest'].unique())
# Out:
# ['M1979787155' 'M2044282225' 'C553264065' ... 'C1850423904' 'C1881841831'
#  'C2080388513']

# %%
print(data['nameDest'].nunique())
# Out:
# 2722362
